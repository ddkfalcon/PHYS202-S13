# %% [markdown]
# Electric Dipole Equation
# =

# %% [markdown]
# \begin{equation}
# V(x,y) = \frac{kq}{\sqrt{x^2 + (y - d)^2}} - \frac{kq}{\sqrt{x^2 + (y + d)^2}}
# \end{equation}

# %%
#make the x-y grid to cover the plane -2 < x < 2 and -2 < y < 2
dx = 0.06
dy = 0.06
x = arange(-2., 2., dx)
y = arange(-2., 2., dy)
print x.ndim
print len(x)
# Out:
# 1
# 67

# %%
X, Y = meshgrid(x,y)
print X.ndim
print Y.shape
print X
print Y
# Out:
# 2
# (67, 67)
# [[-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  ...,
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]
#  [-2.   -1.94 -1.88 ...,  1.84  1.9   1.96]]
# [[-2.   -2.   -2.   ..., -2.   -2.   -2.  ]
#  [-1.94 -1.94 -1.94 ..., -1.94 -1.94 -1.94]
#  [-1.88 -1.88 -1.88 ..., -1.88 -1.88 -1.88]
#  ...,
#  [ 1.84  1.84  1.84 ...,  1.84  1.84  1.84]
#  [ 1.9   1.9   1.9  ...,  1.9   1.9   1.9 ]
#  [ 1.96  1.96  1.96 ...,  1.96  1.96  1.96]]

# %%
#make the function, V(x,y)
k = 1; q = 1; d = 1
V = (k*q/(X**2 + (Y - d)**2)**(1/2.)) - (k*q/(X**2 + (Y + d)**2)**(1/2.))
print V
# Out:
# [[-0.1698635  -0.17826925 -0.18715865 ..., -0.19336737 -0.18414007
#   -0.17541494]
#  [-0.17127992 -0.17998007 -0.18920149 ..., -0.19565471 -0.18606779
#   -0.17702367]
#  [-0.17245961 -0.18144664 -0.19099347 ..., -0.19768747 -0.18774672
#   -0.17839056]
#  ...,
#  [ 0.17310174  0.18227437  0.19203282 ...,  0.19888408  0.18871243
#    0.17915368]
#  [ 0.17209427  0.1809867   0.19042599 ...,  0.19704029  0.18721662
#    0.1779635 ]
#  [ 0.17083282  0.17943553  0.18854686 ...,  0.19491887  0.18545135
#    0.17651294]]

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(X, Y, V, rstride = 1, cstride = 1, linewidth = 0, cmap = cm.winter_r)
#help(Axes3D.plot_surface)
cb = fig.colorbar(p, shrink = 0.5)

# %%
#Represent 3D data by contours
levels = array([8, 4, 2, 1, 0.5, 0.25, 0, -0.25, -0.5, -1, -2, -4, -8])
contour(X, Y, V, levels, linewidths = 2, cmap = cm.winter_r)
show()

# %% [markdown]
# Ex 1. Make 3D plot
# -

# %%
dx = 12./51.
dy = 12./51.
x = arange(-6., 6., dx)
y = arange(-6., 6., dy)
X,Y = meshgrid(x,y)
G = e**(-X**2 - Y**2)
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(X, Y, G, rstride = 1, cstride = 1, linewidth = 0, cmap = cm.winter_r)
#help(Axes3D.plot_surface)
cb = fig.colorbar(p, shrink = 0.5)

# %% [markdown]
# Ex 2. Electric Potential
# -

# %%
dx = 8./101.
dy = 8./101.
x = arange(-4., 4., dx)
y = arange(-4., 4., dy)
X,Y = meshgrid(x,y)
k = 8.9875517873681764*(10**9) #N m^2 C^-2
q = 10**-9 #Coulombs
d = 2 #meters
V = (k*q/(X**2 + (Y - d)**2)**(1/2.)) + (k*q/(X**2 + (Y + d)**2)**(1/2.))
U = -((k*q/(Y**2 + (X - d)**2)**(1/2.)) + (k*q/(Y**2 + (X + d)**2)**(1/2.)))
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(X, Y, V+U, rstride = 1, cstride = 1, linewidth = 0, cmap = cm.prism_r)
cb = fig.colorbar(p, shrink = 0.5)

# %%
levels = array([8, 4, 2, 1, 0.5, 0.25, 0, -0.25, -0.5, -1, -2, -4, -8])
contour(X, Y, V + U, levels, linewidths = 2, cmap = cm.winter_r)
show()

# %% [markdown]
# 3.
# -

# %% [markdown]
# a)

# %%
def pointPotential(X, Y, q, posx, posy):
    #Returns electric potential due to given charge
    k = 8.9875517873681764*(10**9) #N m^2 C^-2
    Vxy = (k*q/((X - posx)**2 + (Y - posy)**2)**(1/2.)) #- (k*q/(X**2 + (Y + posy)**2)**(1/2.))
    return Vxy
dx = 0.06
dy = 0.06
x = arange(-2., 2., dx)
y = arange(-2., 2., dy)
X,Y = meshgrid(x,y)
V11 = pointPotential(X, Y, 1, 1., 1.)
print V11
# Out:
# [[  2.11838627e+09   2.13967496e+09   2.16116864e+09 ...,   2.88489633e+09
#     2.86950445e+09   2.85332045e+09]
#  [  2.13967496e+09   2.16161864e+09   2.18378733e+09 ...,   2.93936948e+09
#     2.92309409e+09   2.90599176e+09]
#  [  2.16116864e+09   2.18378733e+09   2.20665237e+09 ...,   2.99585060e+09
#     2.97862439e+09   2.96053482e+09]
#  ...,
#  [  2.88489633e+09   2.93936948e+09   2.99585060e+09 ...,   7.56566526e+09
#     7.30044120e+09   7.04564794e+09]
#  [  2.86950445e+09   2.92309409e+09   2.97862439e+09 ...,   7.30044120e+09
#     7.06128757e+09   6.82995146e+09]
#  [  2.85332045e+09   2.90599176e+09   2.96053482e+09 ...,   7.04564794e+09
#     6.82995146e+09   6.61995710e+09]]

# %% [markdown]
# b)

# %%
def dipolePotential(x, y, q, d):
    #returns the dipole potential 
    k = 8.9875517873681764*(10**9) #N m^2 C^-2
    X,Y = meshgrid(x,y)
    Vxy = (k*q/(X**2 + (Y - d)**2)**(1/2.)) + (k*q/(X**2 + (Y + d)**2)**(1/2.))
    #Uxy = -((k*q/(Y**2 + (X - d)**2)**(1/2.)) + (k*q/(Y**2 + (X + d)**2)**(1/2.)))
    return Vxy #+ Uxy
dx = 8./101.
dy = 8./101.
x = arange(-4., 4., dx)
y = arange(-4., 4., dy)
V22 = dipolePotential(x,y, 1e-9, 2.)
print V22
# Out:
# [[ 3.25602686  3.29589711  3.33666471 ...,  3.37835656  3.33666471
#    3.29589711]
#  [ 3.28328612  3.32414856  3.36595926 ...,  3.40874854  3.36595926
#    3.32414856]
#  [ 3.31042653  3.35228673  3.39514726 ...,  3.43904207  3.39514726
#    3.35228673]
#  ...,
#  [ 3.33741863  3.38028022  3.42419527 ...,  3.46920149  3.42419527
#    3.38028022]
#  [ 3.31042653  3.35228673  3.39514726 ...,  3.43904207  3.39514726
#    3.35228673]
#  [ 3.28328612  3.32414856  3.36595926 ...,  3.40874854  3.36595926
#    3.32414856]]

# %% [markdown]
# c)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection = '3d')
dx = 0.06
dy = 0.06
x = arange(-2., 2., dx)
y = arange(-2., 2., dy)
X,Y = meshgrid(x,y)
p = ax.plot_surface(X, Y, V11, rstride = 1, cstride = 1, linewidth = 0, cmap = cm.winter_r)
#help(Axes3D.plot_surface)
cb = fig.colorbar(p, shrink = 0.5)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection = '3d')
dx = 8./101.
dy = 8./101.
x = arange(-4., 4., dx)
y = arange(-4., 4., dy)
X,Y = meshgrid(x,y)
p = ax.plot_surface(X, Y, V22, rstride = 1, cstride = 1, linewidth = 0, cmap = cm.winter_r)
#help(Axes3D.plot_surface)
cb = fig.colorbar(p, shrink = 0.5)
