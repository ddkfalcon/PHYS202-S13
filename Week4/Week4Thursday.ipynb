# %%
from Electrostatics import *

# %%
x = arange(-2., 2., 0.06)
y = arange(-2., 2., 0.06)
X,Y = meshgrid(x,y)
q = -2e-9
posx = 0.
posy = -0.5e-3
V11 = pointPotential(X, Y, q, posx, posy)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(X, Y, V11, rstride = 1, cstride = 1, linewidth = 0, cmap = cm.prism)
cb = fig.colorbar(p, shrink = 0.5)

# %%
dx = 8./101.
dy = 8./101.
x = arange(-4., 4., dx)
y = arange(-4., 4., dy)
X, Y = meshgrid(x,y)
q = 3e-9
d = 1e-3
V22 = dipolePotential(X, Y, q, d)
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection = '3d')
p = ax.plot_surface(X, Y, V22, rstride = 1, cstride = 1, linewidth = 0, cmap = cm.prism)
cb = fig.colorbar(p, shrink = 0.5)

# %% [markdown]
# Using Boolean Masks For Finding Data
# =

# %%
theta = arange(0., 2*pi , pi/100)
plot(theta, sin(theta))
show()

# %%
mask = (sin(theta) > 0) & (sin(theta) < 0.5)
#print mask
plot(theta, sin(theta), theta[mask], sin(theta[mask]))
# Out:
# [<matplotlib.lines.Line2D at 0x10aabd2d0>,
#  <matplotlib.lines.Line2D at 0x10aabdd90>]

# %%
y = sin(theta[mask])
jj = (y == max(y))
y[jj] = NaN
plot(theta, sin(theta))
plot(theta[mask], y, linewidth = 4)
show()

# %% [markdown]
# Interpolation
# =

# %%
theta = arange(0., 2*pi + 0.01, pi/10)
mask = (theta == 0.5)
#print mask

# %%
newTheta = 0.5; newSin = 0.
from scipy.interpolate import interp1d
#help(interp1d)
sinInterp = interp1d(theta, sin(theta))
newSin = sinInterp(newTheta)
print newSin
plot(theta, sin(theta), newTheta, newSin, 'r+', markersize = 20, markeredgewidth = 3)
show()
# Out:
# 0.473922198704

# %%
thetaNew = arange(0, 2*pi + 0.1, pi/30)
sinNew = interp1d(theta, sin(theta))(thetaNew)
plot(theta, sin(theta), thetaNew, sinNew, 'r.')
# Out:
# [<matplotlib.lines.Line2D at 0x10e07c110>,
#  <matplotlib.lines.Line2D at 0x10e07c5d0>]

# %%
plot(thetaNew, sinNew - sin(thetaNew))
ylabel('difference between interp and exact values')
show()

# %%
sinNewC = interp1d(theta, sin(theta), kind = 'cubic')(thetaNew)
subplot(2,1,1)
plot(thetaNew, sinNew - sin(thetaNew), thetaNew, sinNewC - sin(thetaNew), 'r')
subplot(2, 1, 2)
plot(thetaNew, sinNewC - sin(thetaNew), 'r')
show()

# %% [markdown]
# Differentiation
# =

# %%
x = arange(0., 10.01,0.1)
y = x**5

# %%
plot(x,y)

# %%
dy = diff(y) #y(n+1) - y(n)
#help(diff)
print len(y), len(dy)
dx = diff(x)
dydx = dy/dx
print len(dydx)
# Out:
# 101 100
# 100

# %%
dydx1 = zeros(y.shape, float)
dydx1[:-1] = diff(y)/diff(x)
dydx1[-1] = (y[-1] - y[-2])/(x[-1] - x[-2])

# %% [markdown]
# \begin{equation}
#     y = x**5
# \end{equation}
# ,
# \begin{equation}
#     \frac{dy}{dx} = 5x**4
# \end{equation}

# %%
dydxExact = 5*x**4

# %%
plot(x, dydx1, x, dydxExact)
# Out:
# [<matplotlib.lines.Line2D at 0x10c990410>,
#  <matplotlib.lines.Line2D at 0x10c990510>]
